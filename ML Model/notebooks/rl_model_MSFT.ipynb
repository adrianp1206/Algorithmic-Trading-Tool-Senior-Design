# %%
import sys
import os

# Get the absolute path to the `src` directory
src_path = os.path.abspath(os.path.join('..', 'src'))

# Add the `src` directory to the Python path
if src_path not in sys.path:
    sys.path.append(src_path)

from create_rl_input import generate_rl_input_data

ticker = "TSLA"
lstm_model_path = "../tests/lstm/lstm_MSFT_model.h5"      # Replace with your actual LSTM model path
xgb_model_path = "../tests/boost/xgboost_MSFT.joblib"        # Replace with your actual XGBoost model path
raw_stock_csv = "MSFT_data.csv"         # Replace with your raw CSV file path
start_date = "2010-06-01"
end_date = "2022-01-01"
feature_subset = ['STOCH_fastd', 'PLUS_DM', 'TRANGE', 'HT_TRENDMODE', 'STOCH_fastk', 'ADOSC', 'STOCH_slowd']

    # Generate the RL input DataFrame
df_rl_input = generate_rl_input_data(
    raw_csv_path=raw_stock_csv,
    ticker=ticker,
    lstm_model_path=lstm_model_path,
    xgb_model_path=xgb_model_path,
    start_date=start_date,
    end_date=end_date,
    feature_subset=feature_subset
)

output_csv = "MSFT_RL_input.csv"
print(df_rl_input.head())
df_rl_input.to_csv(output_csv, index=False, header=True)
# Out:
# CALCULATED TECHNICALS
#          Date      Close       High        Low       Open     Volume  \
# 0  2010-06-22  19.540419  20.056037  19.532836  19.836140   55985400
# 1  2010-06-23  19.191614  19.547998  19.123370  19.547998   61466200
# 2  2010-06-24  18.956553  19.502501  18.903474  19.305352   85243400
# 3  2010-06-25  18.600161  19.039952  18.433342  18.994456  156256700
# 4  2010-06-28  18.433352  18.660831  18.289283  18.585005   73784800
#
#    XGB_Pred  XGB_Prob_Up
# 0         0     0.011226
# 1         0     0.085885
# 2         0     0.044069
# 3         0     0.053305
# 4         0     0.052651

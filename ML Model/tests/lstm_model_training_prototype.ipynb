# %%
import sys
import os

# Get the absolute path to the `src` directory
src_path = os.path.abspath(os.path.join('..', 'src'))

# Add the `src` directory to the Python path
if src_path not in sys.path:
    sys.path.append(src_path)

from train_lstm import train_lstm_model

print("Training and validation metrics for TSLA: High Volatility")
train_lstm_model('TSLA')
# Out:
# Training and validation metrics for TSLA: High Volatility
# [*********************100%***********************]  1 of 1 completed
# 2024-11-20 15:55:42.505291: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M3 Pro
# 2024-11-20 15:55:42.505313: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 18.00 GB
# 2024-11-20 15:55:42.505321: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 6.00 GB
# 2024-11-20 15:55:42.505335: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-11-20 15:55:42.505343: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# ...

# %%
import sys
import os

# Get the absolute path to the `src` directory
src_path = os.path.abspath(os.path.join('..', 'src'))

# Add the `src` directory to the Python path
if src_path not in sys.path:
    sys.path.append(src_path)

from train_lstm import train_lstm_model

print("Training and validation metrics for MSFT: Medium Volatility")
train_lstm_model('MSFT')
# Out:
# Training and validation metrics for MSFT: Medium Volatility
# [*********************100%***********************]  1 of 1 completed
# Final Training Loss: 0.0000
# Final Validation Loss: 0.0001
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Test Loss: 0.0014, Test MSE: 0.0014
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
#
# Mean Absolute Percentage Error (MAPE) for Test Set: 3.97%
# Root Mean Squared Error (RMSE) for Test Set: 11.98
# R² Score for Test Set: 0.9479

# %%
import sys
import os

# Get the absolute path to the `src` directory
src_path = os.path.abspath(os.path.join('..', 'src'))

# Add the `src` directory to the Python path
if src_path not in sys.path:
    sys.path.append(src_path)

from train_lstm import train_lstm_model

print("Training and validation metrics for KO: Low Volatility")
train_lstm_model('KO')
# Out:
# [*********************100%***********************]  1 of 1 completed
# Training and validation metrics for KO: Low Volatility
# Final Training Loss: 0.0001
# Final Validation Loss: 0.0002
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Test Loss: 0.0008, Test MSE: 0.0008
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
#
# Mean Absolute Percentage Error (MAPE) for Test Set: 1.87%
# Root Mean Squared Error (RMSE) for Test Set: 1.24
# R² Score for Test Set: 0.9109
